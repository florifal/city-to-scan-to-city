# %%
from experiment.scenario import *
from experiment_setup.exp_utrecht_10_492_594_v2_setup import *
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# # Setup

# %% [markdown]
# Set up experiment:

# %%
load_existing_experiment = True

if not load_existing_experiment:
    e = Experiment(experiment_name, experiment_dirpath, default_config, scenario_settings, scene_parts)

    print("\nSetting up experiment:")
    e.setup()
else:
    print("\nLoading existing experiment:")
    e = Experiment.load(experiment_dirpath / experiment_name, load_scenarios=True)
# Out:
# Loading existing experiment:
#
# Loading experiment configuration ...
# Initializing experiment ...
# Loading scenarios ...
# - 143 scenarios

# %% [markdown]
# # Try reconstruction with different parameter sets

# %%
scenario_id = 0
e[scenario_id].setup_reconstruction_optimization()
e[scenario_id].recon_optim.load_optim_experiment()
# Out:
# Setting up reconstruction optimization ...
# - Setting up experiment ...
# - Setting up optimizer ...
#
# Loading experiment configuration ...
# File `scenario_settings.json` not found.
# Initializing experiment ...
# Loading scenarios ...
# - 51 scenarios

# %%
optim_scenario_id = 0
params = e[scenario_id].recon_optim.optim_experiment[optim_scenario_id].geoflow_parameters
print(json.dumps(params, indent=2, ensure_ascii=False))
# Out:
# {
#   "r_plane_epsilon": 0.2,
#   "r_plane_k": 15,
#   "r_plane_min_points": 15,
#   "r_plane_normal_angle": 0.75,
#   "thres_alpha": 0.25,
#   "r_line_epsilon": 0.4,
#   "thres_reg_line_dist": 0.5,
#   "thres_reg_line_ext": 1.5,
#   "r_optimisation_data_term": 7.0,
#   "r_normal_k": 5
# }

# %%
e[scenario_id].set_reconstruction_params(params)

# %%
e[scenario_id].setup_reconstruction()
e[scenario_id].prepare_reconstruction()
e[scenario_id].run_reconstruction()

# %% [markdown]
# # Select best optimization scenario

# %%
scenario_id = 49

# %%
e[scenario_id].setup_reconstruction_optimization()

# %%
e[scenario_id].recon_optim.load_optim_experiment()

# %%
e[scenario_id].recon_optim.target_metric

# %%
e[scenario_id].recon_optim.select_optimal_scenario()

# %% [markdown]
# # Rerun individual optimization scenarios
#
# Mostly in cases where the Geoflow output is damaged.

# %%
optim_id = 31
e[scenario_id].recon_optim.optim_experiment[optim_id].setup_reconstruction()
e[scenario_id].recon_optim.optim_experiment[optim_id].prepare_reconstruction()
e[scenario_id].recon_optim.optim_experiment[optim_id].run_reconstruction(add_geoflow_params=e[scenario_id].recon_optim.add_geoflow_params)

# %%
e[scenario_id].recon_optim.optim_experiment[optim_id].setup_evaluation(lods=["2.2"])
e[scenario_id].recon_optim.optim_experiment[optim_id].run_evaluation(evaluator_selection="hausdorff")

# %% [markdown]
# # Full indpendent optimization + renaming
#
# Perform a full independent optimization experiment for a point cloud scenario even though the optimization experiment with this name exists already by renaming the new optimization experiment before execution.

# %%
scenario_id = 80

# %%
e[scenario_id].setup_reconstruction_optimization(recon_timeout=600)
# Out:
# Setting up reconstruction optimization ...
# - Setting up experiment ...
# - Setting up optimizer ...

# %% [markdown]
# Create the required experiment folders so that it can be renamed. Then, rename it and change the corresponding variables of the `ReconstructionOptimization` instance.

# %%
e[scenario_id].recon_optim.optim_experiment.dirpath.mkdir()
e[scenario_id].recon_optim.optim_experiment.settings_dirpath.mkdir()

# %%
e[scenario_id].recon_optim.optim_experiment.rename("scenario_080_full_optim")
# Out:
# Renaming experiment from `scenario_080` to `scenario_080_full_optim` ...
# Saving experiment configuration ...
# Saving scenario configurations ...
# WindowsPath('C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim')

# %%
e[scenario_id].recon_optim.output_dirpath = e[scenario_id].recon_optim.optim_experiment.dirpath

# %% [markdown]
# Now, the `prepare()` method can be called, which sets up the logger in the correct folder with the new name. Add the default parameter set for probing and run the optimization.

# %%
e[scenario_id].recon_optim.prepare()
# Out:
# Preparing reconstruction optimization ...
# Saving experiment configuration ...
# Saving scenario configurations ...
# - Setting up logger ...

# %%
geoflow_default_params_for_optim = {
    k: glb.geoflow_parameters_default[k]
    for k in [k2.split("_", 1)[1] for k2 in glb.geoflow_optim_parameter_space_narrow_2.keys()]
}

# %%
e[scenario_id].recon_optim.optimizer.probe(
    params=geoflow_default_params_for_optim,
    lazy=True
)

# %%
e[scenario_id].run_reconstruction_optimization(init_points=40, n_iter=160)
# Out:
# Running reconstruction optimization ...
#
# Starting optimization scenario 'optim_0000' with the following settings:
# {
#   "r_line_epsilon": 0.4,
#   "r_optimisation_data_term": 7.0,
#   "r_plane_epsilon": 0.2,
#   "r_plane_min_points": 15,
#   "thres_alpha": 0.25,
#   "thres_reg_line_dist": 0.5,
#   "thres_reg_line_ext": 1.5,
#   "r_plane_k": 15,
#   "scenario_name": "optim_0000"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0000/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0000/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0000\geoflow_log_241012-110957.txt
#
# Finished 3D building reconstruction after 0:00:28.523133.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.133026.
#
# Reconstruction in optim_0000 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0000\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:05.707854.
#
# Results of optimization scenario `optim_0000`:
# hausdorff
# - hausdorff_22_rms: 2.258456302513927
# - rms_min_dist_22_mean: 0.23044420666140045
#
# Finished optimization scenario `optim_0000` after 0:00:34.795534.
# - Target value: -0.23044420666140045
#
# Starting optimization scenario 'optim_0001' with the following settings:
# {
#   "r_line_epsilon": 0.2502881298363997,
#   "r_optimisation_data_term": 6.7776319022784515,
#   "r_plane_epsilon": 0.5402728227389418,
#   "r_plane_min_points": 29,
#   "thres_alpha": 0.21700807624616794,
#   "thres_reg_line_dist": 0.12352631619463053,
#   "thres_reg_line_ext": 2.5948888812620785,
#   "r_plane_k": 29,
#   "scenario_name": "optim_0001"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0001/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0001/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0001\geoflow_log_241012-111032.txt
#
# Finished 3D building reconstruction after 0:00:23.582907.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.067001.
#
# Reconstruction in optim_0001 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0001\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:04.497802.
#
# Results of optimization scenario `optim_0001`:
# hausdorff
# - hausdorff_22_rms: 2.3217425208551234
# - rms_min_dist_22_mean: 0.20769949971135918
#
# Finished optimization scenario `optim_0001` after 0:00:28.496819.
# - Target value: -0.20769949971135918
#
# Starting optimization scenario 'optim_0002' with the following settings:
# {
#   "r_line_epsilon": 0.615206775084059,
#   "r_optimisation_data_term": 8.073306541227359,
#   "r_plane_epsilon": 1.8693600017611758,
#   "r_plane_min_points": 20,
#   "thres_alpha": 0.3748081216791562,
#   "thres_reg_line_dist": 0.5592967429702469,
#   "thres_reg_line_ext": 2.714628695515687,
#   "r_plane_k": 20,
#   "scenario_name": "optim_0002"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0002/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0002/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0002\geoflow_log_241012-111100.txt
#
# Finished 3D building reconstruction after 0:00:32.346541.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.125521.
#
# Reconstruction in optim_0002 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0002\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:08.483356.
#
# Results of optimization scenario `optim_0002`:
# hausdorff
# - hausdorff_22_rms: 1.9966389759092456
# - rms_min_dist_22_mean: 0.21873642602423835
#
# Finished optimization scenario `optim_0002` after 0:00:42.375369.
# - Target value: -0.21873642602423835
#
# Starting optimization scenario 'optim_0003' with the following settings:
# {
#   "r_line_epsilon": 0.6219981972387555,
#   "r_optimisation_data_term": 8.996789640446135,
#   "r_plane_epsilon": 1.2619212921813179,
#   "r_plane_min_points": 28,
#   "thres_alpha": 0.993522951409241,
#   "thres_reg_line_dist": 0.3780484842619889,
#   "thres_reg_line_ext": 2.145023021659004,
#   "r_plane_k": 28,
#   "scenario_name": "optim_0003"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0003/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0003/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0003\geoflow_log_241012-111143.txt
#
# Finished 3D building reconstruction after 0:00:25.908593.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.073602.
#
# Reconstruction in optim_0003 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0003\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:04.671164.
#
# Results of optimization scenario `optim_0003`:
# hausdorff
# - hausdorff_22_rms: 1.858177668319257
# - rms_min_dist_22_mean: 0.1950900186367036
#
# Finished optimization scenario `optim_0003` after 0:00:31.089518.
# - Target value: -0.1950900186367036
#
# Starting optimization scenario 'optim_0004' with the following settings:
# {
#   "r_line_epsilon": 0.8315935356850471,
#   "r_optimisation_data_term": 5.606658582783919,
#   "r_plane_epsilon": 0.3647700357254331,
#   "r_plane_min_points": 15,
#   "thres_alpha": 0.6203530952692392,
#   "thres_reg_line_dist": 0.2651403173584269,
#   "thres_reg_line_ext": 1.7739980336273042,
#   "r_plane_k": 15,
#   "scenario_name": "optim_0004"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0004/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0004/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0004\geoflow_log_241012-111214.txt
#
# Finished 3D building reconstruction after 0:00:24.466122.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.084038.
#
# Reconstruction in optim_0004 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0004\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:04.360533.
#
# Results of optimization scenario `optim_0004`:
# hausdorff
# - hausdorff_22_rms: 1.9738513567106037
# - rms_min_dist_22_mean: 0.18509131222916156
#
# Finished optimization scenario `optim_0004` after 0:00:29.265371.
# - Target value: -0.18509131222916156
#
# Starting optimization scenario 'optim_0005' with the following settings:
# {
#   "r_line_epsilon": 0.5730964023092282,
#   "r_optimisation_data_term": 9.474463193490106,
#   "r_plane_epsilon": 0.9467863317648559,
#   "r_plane_min_points": 13,
#   "thres_alpha": 0.46732091327598146,
#   "thres_reg_line_dist": 0.8182417150373078,
#   "thres_reg_line_ext": 1.3167388600996366,
#   "r_plane_k": 13,
#   "scenario_name": "optim_0005"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0005/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0005/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0005\geoflow_log_241012-111243.txt
#
# Finished 3D building reconstruction after 0:00:31.852990.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.074511.
#
# Reconstruction in optim_0005 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0005\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:04.713213.
#
# Results of optimization scenario `optim_0005`:
# hausdorff
# - hausdorff_22_rms: 2.049209767666961
# - rms_min_dist_22_mean: 0.20719934986160668
#
# Finished optimization scenario `optim_0005` after 0:00:37.013911.
# - Target value: -0.20719934986160668
#
# Starting optimization scenario 'optim_0006' with the following settings:
# {
#   "r_line_epsilon": 0.536940022427399,
#   "r_optimisation_data_term": 9.01177359078999,
#   "r_plane_epsilon": 0.8458283870216016,
#   "r_plane_min_points": 10,
#   "thres_alpha": 0.5381511605717,
#   "thres_reg_line_dist": 0.5207277583257723,
#   "thres_reg_line_ext": 1.1100645259501714,
#   "r_plane_k": 10,
#   "scenario_name": "optim_0006"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0006/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0006/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0006\geoflow_log_241012-111320.txt
#
# Finished 3D building reconstruction after 0:00:28.831951.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.079587.
#
# Reconstruction in optim_0006 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0006\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:04.769500.
#
# Results of optimization scenario `optim_0006`:
# hausdorff
# - hausdorff_22_rms: 2.1332427754074534
# - rms_min_dist_22_mean: 0.21725297136541116
#
# Finished optimization scenario `optim_0006` after 0:00:34.149921.
# - Target value: -0.21725297136541116
#
# Starting optimization scenario 'optim_0007' with the following settings:
# {
#   "r_line_epsilon": 0.4940604204551934,
#   "r_optimisation_data_term": 5.201845361930067,
#   "r_plane_epsilon": 0.7149191699556229,
#   "r_plane_min_points": 15,
#   "thres_alpha": 0.9329568002967842,
#   "thres_reg_line_dist": 0.49094864548942907,
#   "thres_reg_line_ext": 1.0114998071724088,
#   "r_plane_k": 15,
#   "scenario_name": "optim_0007"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0007/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0007/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0007\geoflow_log_241012-111354.txt
#
# Finished 3D building reconstruction after 0:00:25.791511.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.066993.
#
# Reconstruction in optim_0007 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0007\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:04.295491.
#
# Results of optimization scenario `optim_0007`:
# hausdorff
# - hausdorff_22_rms: 2.2410319635967664
# - rms_min_dist_22_mean: 0.23522731879449618
#
# Finished optimization scenario `optim_0007` after 0:00:30.482678.
# - Target value: -0.23522731879449618
#
# Starting optimization scenario 'optim_0008' with the following settings:
# {
# ...
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:05.790200.
#
# Results of optimization scenario `optim_0198`:
# hausdorff
# - hausdorff_22_rms: 1.6701834364568693
# - rms_min_dist_22_mean: 0.18086450495224993
#
# Finished optimization scenario `optim_0198` after 0:00:47.876835.
# - Target value: -0.18086450495224993
#
# Starting optimization scenario 'optim_0199' with the following settings:
# {
#   "r_line_epsilon": 1.0,
#   "r_optimisation_data_term": 9.168944898373615,
#   "r_plane_epsilon": 0.7701881769434483,
#   "r_plane_min_points": 28,
#   "thres_alpha": 0.900126862418903,
#   "thres_reg_line_dist": 1.0,
#   "thres_reg_line_ext": 1.1949979436133211,
#   "r_plane_k": 28,
#   "scenario_name": "optim_0199"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0199/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0199/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0199\geoflow_log_241012-130154.txt
#
# Finished 3D building reconstruction after 0:00:21.855009.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.060033.
#
# Reconstruction in optim_0199 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0199\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:04.381290.
#
# Results of optimization scenario `optim_0199`:
# hausdorff
# - hausdorff_22_rms: 1.7628477531379703
# - rms_min_dist_22_mean: 0.17759939271672281
#
# Finished optimization scenario `optim_0199` after 0:00:26.675267.
# - Target value: -0.17759939271672281
#
# Starting optimization scenario 'optim_0200' with the following settings:
# {
#   "r_line_epsilon": 0.49538794841402223,
#   "r_optimisation_data_term": 8.917428443027557,
#   "r_plane_epsilon": 0.6994551568789893,
#   "r_plane_min_points": 11,
#   "thres_alpha": 0.7959570788636757,
#   "thres_reg_line_dist": 0.23237344155587278,
#   "thres_reg_line_ext": 1.077196313235333,
#   "r_plane_k": 11,
#   "scenario_name": "optim_0200"
# }
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0200/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_080_full_optim/07_reconstruction/optim_0200/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0200\geoflow_log_241012-130221.txt
#
# Finished 3D building reconstruction after 0:00:23.752872.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.070586.
#
# Reconstruction in optim_0200 yielded 99 buildings.
#
# Checking for outlier vertices ...
# - None found.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_080_full_optim\07_reconstruction\optim_0200\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# NL.IMBAG.Pand.0344100000000031.obj NL.IMBAG.Pand.0344100000000032.obj NL.IMBAG.Pand.0344100000001647.obj NL.IMBAG.Pand.0344100000002647.obj NL.IMBAG.Pand.0344100000002887.obj NL.IMBAG.Pand.0344100000006576.obj NL.IMBAG.Pand.0344100000006579.obj NL.IMBAG.Pand.0344100000006784.obj NL.IMBAG.Pand.0344100000006948.obj NL.IMBAG.Pand.0344100000007444.obj NL.IMBAG.Pand.0344100000007592.obj NL.IMBAG.Pand.0344100000007593.obj NL.IMBAG.Pand.0344100000007839.obj NL.IMBAG.Pand.0344100000008425.obj NL.IMBAG.Pand.0344100000009179.obj NL.IMBAG.Pand.0344100000010308.obj NL.IMBAG.Pand.0344100000012472.obj NL.IMBAG.Pand.0344100000012706.obj NL.IMBAG.Pand.0344100000013246.obj NL.IMBAG.Pand.0344100000014287.obj NL.IMBAG.Pand.0344100000016994.obj NL.IMBAG.Pand.0344100000016995.obj NL.IMBAG.Pand.0344100000018471.obj NL.IMBAG.Pand.0344100000018599.obj NL.IMBAG.Pand.0344100000018693.obj NL.IMBAG.Pand.0344100000020588.obj NL.IMBAG.Pand.0344100000021043.obj NL.IMBAG.Pand.0344100000021100.obj NL.IMBAG.Pand.0344100000021392.obj NL.IMBAG.Pand.0344100000023356.obj NL.IMBAG.Pand.0344100000023398.obj NL.IMBAG.Pand.0344100000023960.obj NL.IMBAG.Pand.0344100000025071.obj NL.IMBAG.Pand.0344100000025328.obj NL.IMBAG.Pand.0344100000029691.obj NL.IMBAG.Pand.0344100000029796.obj NL.IMBAG.Pand.0344100000031236.obj NL.IMBAG.Pand.0344100000031458.obj NL.IMBAG.Pand.0344100000031569.obj NL.IMBAG.Pand.0344100000032982.obj NL.IMBAG.Pand.0344100000034246.obj NL.IMBAG.Pand.0344100000034376.obj NL.IMBAG.Pand.0344100000036005.obj NL.IMBAG.Pand.0344100000036764.obj NL.IMBAG.Pand.0344100000038796.obj NL.IMBAG.Pand.0344100000039696.obj NL.IMBAG.Pand.0344100000039888.obj NL.IMBAG.Pand.0344100000040697.obj NL.IMBAG.Pand.0344100000042140.obj NL.IMBAG.Pand.0344100000043638.obj NL.IMBAG.Pand.0344100000044085.obj NL.IMBAG.Pand.0344100000047418.obj NL.IMBAG.Pand.0344100000048104.obj NL.IMBAG.Pand.0344100000049184.obj NL.IMBAG.Pand.0344100000049290.obj NL.IMBAG.Pand.0344100000050441.obj NL.IMBAG.Pand.0344100000050464.obj NL.IMBAG.Pand.0344100000051399.obj NL.IMBAG.Pand.0344100000051985.obj NL.IMBAG.Pand.0344100000053331.obj NL.IMBAG.Pand.0344100000053515.obj NL.IMBAG.Pand.0344100000053757.obj NL.IMBAG.Pand.0344100000053758.obj NL.IMBAG.Pand.0344100000054357.obj NL.IMBAG.Pand.0344100000054944.obj NL.IMBAG.Pand.0344100000055100.obj NL.IMBAG.Pand.0344100000055950.obj NL.IMBAG.Pand.0344100000056516.obj NL.IMBAG.Pand.0344100000057046.obj NL.IMBAG.Pand.0344100000060428.obj NL.IMBAG.Pand.0344100000061285.obj NL.IMBAG.Pand.0344100000061759.obj NL.IMBAG.Pand.0344100000062345.obj NL.IMBAG.Pand.0344100000063548.obj NL.IMBAG.Pand.0344100000065612.obj NL.IMBAG.Pand.0344100000067709.obj NL.IMBAG.Pand.0344100000069075.obj NL.IMBAG.Pand.0344100000069294.obj NL.IMBAG.Pand.0344100000070276.obj NL.IMBAG.Pand.0344100000070597.obj NL.IMBAG.Pand.0344100000072795.obj NL.IMBAG.Pand.0344100000073979.obj NL.IMBAG.Pand.0344100000076474.obj NL.IMBAG.Pand.0344100000076488.obj NL.IMBAG.Pand.0344100000077610.obj NL.IMBAG.Pand.0344100000080741.obj NL.IMBAG.Pand.0344100000080884.obj NL.IMBAG.Pand.0344100000081281.obj NL.IMBAG.Pand.0344100000092343.obj NL.IMBAG.Pand.0344100000092839.obj NL.IMBAG.Pand.0344100000092980.obj NL.IMBAG.Pand.0344100000102351.obj NL.IMBAG.Pand.0344100000105035.obj NL.IMBAG.Pand.0344100000126107.obj NL.IMBAG.Pand.0344100000126379.obj NL.IMBAG.Pand.0344100000129560.obj NL.IMBAG.Pand.0344100000137812.obj NL.IMBAG.Pand.0344100000138917.obj NL.IMBAG.Pand.0344100000145618.obj
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:04.606952.
#
# Results of optimization scenario `optim_0200`:
# hausdorff
# - hausdorff_22_rms: 1.9862210349910354
# - rms_min_dist_22_mean: 0.2007641462974536
#
# Finished optimization scenario `optim_0200` after 0:00:28.999202.
# - Target value: -0.2007641462974536
#
# Finished reconstruction optimization experiment `scenario_080` after 1:52:53.097681.
# Best results in terms of `rms_min_dist_22_mean`:
# {
#   "target": -0.1530639295013462,
#   "params": {
#     "r_line_epsilon": 0.7063569008670754,
#     "r_optimisation_data_term": 9.567094718544944,
#     "r_plane_epsilon": 0.4013001841602708,
#     "r_plane_min_points": 12,
#     "thres_alpha": 0.4302678727107927,
#     "thres_reg_line_dist": 0.12408722536354655,
#     "thres_reg_line_ext": 1.758564233904165,
#     "r_plane_k": 12
#   }
# }

# %% [markdown]
# # Rerun optim_0000 (default params) for high-density scenarios
#
# For the last few high-density scenarios, the optimization iteration with Geoflow default parameter values ran into the timeout. But since these results are particularly interesting, it could be cool to run them again without timeout.

# %%
scenario_ids = list(range(116, 121))

for scenario_id in scenario_ids:
    e[scenario_id].setup_reconstruction_optimization()
    e[scenario_id].recon_optim.load_optim_experiment()
    
    add_geoflow_params = {"skip_lod12": True, "skip_lod13": True}
    e[scenario_id].recon_optim.optim_experiment[0].setup_reconstruction(add_geoflow_params=add_geoflow_params, geoflow_timeout=None)
    e[scenario_id].recon_optim.optim_experiment[0].prepare_reconstruction()
    
    e[scenario_id].recon_optim.optim_experiment[0].run_reconstruction()

    e[scenario_id].recon_optim.optim_experiment[0].setup_evaluation(lods="2.2")
    e[scenario_id].recon_optim.optim_experiment[0].run_evaluation(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"])
    
    e[scenario_id].recon_optim.optim_experiment[0].concat_evaluation_results(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"])
    
    e[scenario_id].recon_optim.optim_experiment.run_steps(Scenario.setup_evaluation, lods=["2.2"])
    e[scenario_id].recon_optim.optim_experiment.compute_summary_statistics(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"], ignore_missing=True)
# Out:
# Setting up reconstruction optimization ...
# - Setting up experiment ...
# - Setting up optimizer ...
#
# Loading experiment configuration ...
# File `scenario_settings.json` not found.
# Initializing experiment ...
# Loading scenarios ...
# - 51 scenarios
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_116/07_reconstruction/optim_0000/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_116/07_reconstruction/optim_0000/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_116\07_reconstruction\optim_0000\geoflow_log_241014-191140.txt
#
# Finished 3D building reconstruction after 0:16:22.970975.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.321121.
#
# Reconstruction in optim_0000 yielded 99 buildings.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_116\07_reconstruction\optim_0000\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:33.334491.
#
# Starting ComplexityEvaluator ...
#
# Counting faces for LOD 2.2 ...
#
# Finished ComplexityEvaluator after 0:00:01.641790.
#
# Starting ComplexityDifferenceEvaluator ...
#
# Evaluation results for complexity evaluator 1 already exist. Will not reevaluate.
#
# Evaluation results for complexity evaluator 2 already exist. Will not reevaluate.
#
# Finished ComplexityDifferenceEvaluator after 0:00:00.025573.
#
# Starting GeoflowOutputEvaluator ...
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.331583.
#
# Starting CityJSONBuildingsEvaluator ...
#
# Finished CityJSONBuildingsEvaluator after 0:00:01.408841.
#
# Starting WavefrontOBJBuildingsEvaluator ...
#
# Finished WavefrontOBJBuildingsEvaluator after 0:00:03.259604.
#
# Finished GeoflowOutputEvaluator after 0:00:05.006000.
#
# Running 'setup_evaluation' for optim_0000 ...
#
# Finished 'setup_evaluation' for optim_0000 after 0:00:00.018005.
#
# Running 'setup_evaluation' for optim_0001 ...
#
# Finished 'setup_evaluation' for optim_0001 after 0:00:00.019000.
#
# Running 'setup_evaluation' for optim_0002 ...
#
# Finished 'setup_evaluation' for optim_0002 after 0:00:00.017183.
#
# Running 'setup_evaluation' for optim_0003 ...
#
# Finished 'setup_evaluation' for optim_0003 after 0:00:00.018999.
#
# Running 'setup_evaluation' for optim_0004 ...
#
# Finished 'setup_evaluation' for optim_0004 after 0:00:00.016000.
#
# Running 'setup_evaluation' for optim_0005 ...
#
# Finished 'setup_evaluation' for optim_0005 after 0:00:00.016002.
#
# Running 'setup_evaluation' for optim_0006 ...
#
# Finished 'setup_evaluation' for optim_0006 after 0:00:00.018000.
#
# Running 'setup_evaluation' for optim_0007 ...
#
# Finished 'setup_evaluation' for optim_0007 after 0:00:00.017012.
#
# Running 'setup_evaluation' for optim_0008 ...
#
# Finished 'setup_evaluation' for optim_0008 after 0:00:00.021523.
#
# Running 'setup_evaluation' for optim_0009 ...
#
# Finished 'setup_evaluation' for optim_0009 after 0:00:00.019004.
#
# Running 'setup_evaluation' for optim_0010 ...
#
# Finished 'setup_evaluation' for optim_0010 after 0:00:00.017002.
#
# Running 'setup_evaluation' for optim_0011 ...
#
# Finished 'setup_evaluation' for optim_0011 after 0:00:00.018994.
#
# Running 'setup_evaluation' for optim_0012 ...
#
# Finished 'setup_evaluation' for optim_0012 after 0:00:00.017009.
#
# Running 'setup_evaluation' for optim_0013 ...
#
# Finished 'setup_evaluation' for optim_0013 after 0:00:00.021541.
#
# Running 'setup_evaluation' for optim_0014 ...
#
# Finished 'setup_evaluation' for optim_0014 after 0:00:00.018999.
#
# Running 'setup_evaluation' for optim_0015 ...
#
# Finished 'setup_evaluation' for optim_0015 after 0:00:00.019999.
#
# Running 'setup_evaluation' for optim_0016 ...
#
# Finished 'setup_evaluation' for optim_0016 after 0:00:00.018001.
#
# Running 'setup_evaluation' for optim_0017 ...
#
# Finished 'setup_evaluation' for optim_0017 after 0:00:00.020005.
#
# Running 'setup_evaluation' for optim_0018 ...
#
# Finished 'setup_evaluation' for optim_0018 after 0:00:00.019530.
#
# Running 'setup_evaluation' for optim_0019 ...
#
# Finished 'setup_evaluation' for optim_0019 after 0:00:00.016999.
#
# Running 'setup_evaluation' for optim_0020 ...
#
# Finished 'setup_evaluation' for optim_0020 after 0:00:00.018001.
#
# Running 'setup_evaluation' for optim_0021 ...
#
# Finished 'setup_evaluation' for optim_0021 after 0:00:00.017999.
#
# Running 'setup_evaluation' for optim_0022 ...
#
# Finished 'setup_evaluation' for optim_0022 after 0:00:00.025007.
#
# Running 'setup_evaluation' for optim_0023 ...
#
# Finished 'setup_evaluation' for optim_0023 after 0:00:00.020517.
#
# Running 'setup_evaluation' for optim_0024 ...
#
# Finished 'setup_evaluation' for optim_0024 after 0:00:00.019004.
#
# Running 'setup_evaluation' for optim_0025 ...
#
# Finished 'setup_evaluation' for optim_0025 after 0:00:00.023996.
#
# Running 'setup_evaluation' for optim_0026 ...
#
# Finished 'setup_evaluation' for optim_0026 after 0:00:00.018999.
#
# Running 'setup_evaluation' for optim_0027 ...
#
# Finished 'setup_evaluation' for optim_0027 after 0:00:00.017004.
#
# Running 'setup_evaluation' for optim_0028 ...
#
# Finished 'setup_evaluation' for optim_0028 after 0:00:00.016512.
#
# Running 'setup_evaluation' for optim_0029 ...
#
# Finished 'setup_evaluation' for optim_0029 after 0:00:00.017000.
#
# Running 'setup_evaluation' for optim_0030 ...
#
# Finished 'setup_evaluation' for optim_0030 after 0:00:00.024005.
#
# Running 'setup_evaluation' for optim_0031 ...
#
# Finished 'setup_evaluation' for optim_0031 after 0:00:00.017998.
#
# Running 'setup_evaluation' for optim_0032 ...
#
# Finished 'setup_evaluation' for optim_0032 after 0:00:00.017997.
#
# Running 'setup_evaluation' for optim_0033 ...
#
# Finished 'setup_evaluation' for optim_0033 after 0:00:00.017514.
#
# Running 'setup_evaluation' for optim_0034 ...
#
# Finished 'setup_evaluation' for optim_0034 after 0:00:00.017000.
#
# Running 'setup_evaluation' for optim_0035 ...
#
# Finished 'setup_evaluation' for optim_0035 after 0:00:00.016001.
#
# Running 'setup_evaluation' for optim_0036 ...
#
# Finished 'setup_evaluation' for optim_0036 after 0:00:00.016001.
#
# Running 'setup_evaluation' for optim_0037 ...
#
# Finished 'setup_evaluation' for optim_0037 after 0:00:00.017000.
#
# Running 'setup_evaluation' for optim_0038 ...
#
# Finished 'setup_evaluation' for optim_0038 after 0:00:00.017000.
#
# Running 'setup_evaluation' for optim_0039 ...
#
# Finished 'setup_evaluation' for optim_0039 after 0:00:00.019515.
#
# Running 'setup_evaluation' for optim_0040 ...
#
# Finished 'setup_evaluation' for optim_0040 after 0:00:00.015999.
#
# Running 'setup_evaluation' for optim_0041 ...
#
# Finished 'setup_evaluation' for optim_0041 after 0:00:00.017001.
#
# Running 'setup_evaluation' for optim_0042 ...
#
# Finished 'setup_evaluation' for optim_0042 after 0:00:00.017000.
#
# Running 'setup_evaluation' for optim_0043 ...
#
# Finished 'setup_evaluation' for optim_0043 after 0:00:00.017999.
#
# Running 'setup_evaluation' for optim_0044 ...
#
# Finished 'setup_evaluation' for optim_0044 after 0:00:00.017005.
#
# Running 'setup_evaluation' for optim_0045 ...
#
# Finished 'setup_evaluation' for optim_0045 after 0:00:00.018517.
#
# Running 'setup_evaluation' for optim_0046 ...
#
# Finished 'setup_evaluation' for optim_0046 after 0:00:00.016999.
#
# Running 'setup_evaluation' for optim_0047 ...
#
# Finished 'setup_evaluation' for optim_0047 after 0:00:00.018003.
#
# Running 'setup_evaluation' for optim_0048 ...
#
# Finished 'setup_evaluation' for optim_0048 after 0:00:00.015999.
#
# Running 'setup_evaluation' for optim_0049 ...
#
# Finished 'setup_evaluation' for optim_0049 after 0:00:00.018002.
#
# Running 'setup_evaluation' for optim_0050 ...
#
# Finished 'setup_evaluation' for optim_0050 after 0:00:00.017005.
#
# Finished running 1 step for 51 scenarios after 0:00:00.935407.
#
# Computing summary statistics of 51 scenarios in experiment scenario_116...
#
# WARNING: Reconstruction in optim_0001 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0002 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0003 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0004 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0007 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0008 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0009 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0012 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0016 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0017 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0018 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0019 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0020 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0024 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0025 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0027 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0028 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0029 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0031 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0032 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0033 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0034 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0035 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0036 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0038 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0039 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0045 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0046 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0048 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# Setting up reconstruction optimization ...
# - Setting up experiment ...
# - Setting up optimizer ...
#
# Loading experiment configuration ...
# File `scenario_settings.json` not found.
# Initializing experiment ...
# Loading scenarios ...
# - 51 scenarios
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_117/07_reconstruction/optim_0000/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_117/07_reconstruction/optim_0000/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_117\07_reconstruction\optim_0000\geoflow_log_241014-192846.txt
#
# Finished 3D building reconstruction after 0:18:18.410394.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.593794.
#
# Reconstruction in optim_0000 yielded 99 buildings.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_117\07_reconstruction\optim_0000\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:41.683057.
#
# Starting ComplexityEvaluator ...
#
# Counting faces for LOD 2.2 ...
#
# Finished ComplexityEvaluator after 0:00:01.673267.
#
# Starting ComplexityDifferenceEvaluator ...
#
# Evaluation results for complexity evaluator 1 already exist. Will not reevaluate.
#
# Evaluation results for complexity evaluator 2 already exist. Will not reevaluate.
#
# Finished ComplexityDifferenceEvaluator after 0:00:00.023398.
#
# Starting GeoflowOutputEvaluator ...
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.321824.
#
# Starting CityJSONBuildingsEvaluator ...
#
# Finished CityJSONBuildingsEvaluator after 0:00:01.309962.
#
# Starting WavefrontOBJBuildingsEvaluator ...
#
# Finished WavefrontOBJBuildingsEvaluator after 0:00:01.686582.
#
# Finished GeoflowOutputEvaluator after 0:00:03.321357.
#
# Running 'setup_evaluation' for optim_0000 ...
#
# Finished 'setup_evaluation' for optim_0000 after 0:00:00.012988.
#
# Running 'setup_evaluation' for optim_0001 ...
#
# Finished 'setup_evaluation' for optim_0001 after 0:00:00.016334.
#
# Running 'setup_evaluation' for optim_0002 ...
#
# Finished 'setup_evaluation' for optim_0002 after 0:00:00.015584.
#
# Running 'setup_evaluation' for optim_0003 ...
#
# Finished 'setup_evaluation' for optim_0003 after 0:00:00.016671.
#
# Running 'setup_evaluation' for optim_0004 ...
#
# Finished 'setup_evaluation' for optim_0004 after 0:00:00.016556.
#
# Running 'setup_evaluation' for optim_0005 ...
#
# Finished 'setup_evaluation' for optim_0005 after 0:00:00.016600.
#
# Running 'setup_evaluation' for optim_0006 ...
#
# Finished 'setup_evaluation' for optim_0006 after 0:00:00.017071.
#
# Running 'setup_evaluation' for optim_0007 ...
#
# Finished 'setup_evaluation' for optim_0007 after 0:00:00.017149.
#
# Running 'setup_evaluation' for optim_0008 ...
#
# Finished 'setup_evaluation' for optim_0008 after 0:00:00.014040.
#
# Running 'setup_evaluation' for optim_0009 ...
#
# Finished 'setup_evaluation' for optim_0009 after 0:00:00.015033.
#
# Running 'setup_evaluation' for optim_0010 ...
#
# Finished 'setup_evaluation' for optim_0010 after 0:00:00.015001.
#
# Running 'setup_evaluation' for optim_0011 ...
#
# Finished 'setup_evaluation' for optim_0011 after 0:00:00.017050.
#
# Running 'setup_evaluation' for optim_0012 ...
#
# Finished 'setup_evaluation' for optim_0012 after 0:00:00.015481.
#
# Running 'setup_evaluation' for optim_0013 ...
#
# Finished 'setup_evaluation' for optim_0013 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0014 ...
#
# Finished 'setup_evaluation' for optim_0014 after 0:00:00.014101.
#
# Running 'setup_evaluation' for optim_0015 ...
#
# Finished 'setup_evaluation' for optim_0015 after 0:00:00.018009.
#
# Running 'setup_evaluation' for optim_0016 ...
#
# Finished 'setup_evaluation' for optim_0016 after 0:00:00.016184.
#
# Running 'setup_evaluation' for optim_0017 ...
#
# Finished 'setup_evaluation' for optim_0017 after 0:00:00.015886.
#
# Running 'setup_evaluation' for optim_0018 ...
#
# Finished 'setup_evaluation' for optim_0018 after 0:00:00.014313.
#
# Running 'setup_evaluation' for optim_0019 ...
#
# Finished 'setup_evaluation' for optim_0019 after 0:00:00.015009.
#
# Running 'setup_evaluation' for optim_0020 ...
#
# Finished 'setup_evaluation' for optim_0020 after 0:00:00.015054.
#
# Running 'setup_evaluation' for optim_0021 ...
#
# Finished 'setup_evaluation' for optim_0021 after 0:00:00.015956.
#
# Running 'setup_evaluation' for optim_0022 ...
#
# Finished 'setup_evaluation' for optim_0022 after 0:00:00.014644.
#
# Running 'setup_evaluation' for optim_0023 ...
#
# Finished 'setup_evaluation' for optim_0023 after 0:00:00.015230.
#
# Running 'setup_evaluation' for optim_0024 ...
#
# Finished 'setup_evaluation' for optim_0024 after 0:00:00.015745.
#
# Running 'setup_evaluation' for optim_0025 ...
#
# Finished 'setup_evaluation' for optim_0025 after 0:00:00.015371.
#
# Running 'setup_evaluation' for optim_0026 ...
#
# Finished 'setup_evaluation' for optim_0026 after 0:00:00.014622.
#
# Running 'setup_evaluation' for optim_0027 ...
#
# Finished 'setup_evaluation' for optim_0027 after 0:00:00.016001.
#
# Running 'setup_evaluation' for optim_0028 ...
#
# Finished 'setup_evaluation' for optim_0028 after 0:00:00.015078.
#
# Running 'setup_evaluation' for optim_0029 ...
#
# Finished 'setup_evaluation' for optim_0029 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0030 ...
#
# Finished 'setup_evaluation' for optim_0030 after 0:00:00.015944.
#
# Running 'setup_evaluation' for optim_0031 ...
#
# Finished 'setup_evaluation' for optim_0031 after 0:00:00.014897.
#
# Running 'setup_evaluation' for optim_0032 ...
#
# Finished 'setup_evaluation' for optim_0032 after 0:00:00.014896.
#
# Running 'setup_evaluation' for optim_0033 ...
#
# Finished 'setup_evaluation' for optim_0033 after 0:00:00.016060.
#
# Running 'setup_evaluation' for optim_0034 ...
#
# Finished 'setup_evaluation' for optim_0034 after 0:00:00.014579.
#
# Running 'setup_evaluation' for optim_0035 ...
#
# Finished 'setup_evaluation' for optim_0035 after 0:00:00.015833.
#
# Running 'setup_evaluation' for optim_0036 ...
#
# Finished 'setup_evaluation' for optim_0036 after 0:00:00.015247.
#
# Running 'setup_evaluation' for optim_0037 ...
#
# Finished 'setup_evaluation' for optim_0037 after 0:00:00.015509.
#
# Running 'setup_evaluation' for optim_0038 ...
#
# Finished 'setup_evaluation' for optim_0038 after 0:00:00.014476.
#
# Running 'setup_evaluation' for optim_0039 ...
#
# Finished 'setup_evaluation' for optim_0039 after 0:00:00.016188.
#
# Running 'setup_evaluation' for optim_0040 ...
#
# Finished 'setup_evaluation' for optim_0040 after 0:00:00.015425.
#
# Running 'setup_evaluation' for optim_0041 ...
#
# Finished 'setup_evaluation' for optim_0041 after 0:00:00.015842.
#
# Running 'setup_evaluation' for optim_0042 ...
#
# Finished 'setup_evaluation' for optim_0042 after 0:00:00.014624.
#
# Running 'setup_evaluation' for optim_0043 ...
#
# Finished 'setup_evaluation' for optim_0043 after 0:00:00.014499.
#
# Running 'setup_evaluation' for optim_0044 ...
#
# Finished 'setup_evaluation' for optim_0044 after 0:00:00.016682.
#
# Running 'setup_evaluation' for optim_0045 ...
#
# Finished 'setup_evaluation' for optim_0045 after 0:00:00.014207.
#
# Running 'setup_evaluation' for optim_0046 ...
#
# Finished 'setup_evaluation' for optim_0046 after 0:00:00.015808.
#
# Running 'setup_evaluation' for optim_0047 ...
#
# Finished 'setup_evaluation' for optim_0047 after 0:00:00.014330.
#
# Running 'setup_evaluation' for optim_0048 ...
#
# Finished 'setup_evaluation' for optim_0048 after 0:00:00.015567.
#
# Running 'setup_evaluation' for optim_0049 ...
#
# Finished 'setup_evaluation' for optim_0049 after 0:00:00.018007.
#
# Running 'setup_evaluation' for optim_0050 ...
#
# Finished 'setup_evaluation' for optim_0050 after 0:00:00.014937.
#
# Finished running 1 step for 51 scenarios after 0:00:00.793330.
#
# Computing summary statistics of 51 scenarios in experiment scenario_117...
#
# WARNING: Reconstruction in optim_0001 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0002 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0004 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0005 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0011 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0012 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0013 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0014 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0016 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0017 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0019 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0020 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0026 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0029 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0031 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0036 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0038 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0043 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0044 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0045 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0046 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0050 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# Setting up reconstruction optimization ...
# - Setting up experiment ...
# - Setting up optimizer ...
#
# Loading experiment configuration ...
# File `scenario_settings.json` not found.
# Initializing experiment ...
# Loading scenarios ...
# - 51 scenarios
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_118/07_reconstruction/optim_0000/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_118/07_reconstruction/optim_0000/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_118\07_reconstruction\optim_0000\geoflow_log_241014-194755.txt
#
# Finished 3D building reconstruction after 0:17:44.251575.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.360611.
#
# Reconstruction in optim_0000 yielded 99 buildings.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_118\07_reconstruction\optim_0000\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:33.064080.
#
# Starting ComplexityEvaluator ...
#
# Counting faces for LOD 2.2 ...
#
# Finished ComplexityEvaluator after 0:00:01.671200.
#
# Starting ComplexityDifferenceEvaluator ...
#
# Evaluation results for complexity evaluator 1 already exist. Will not reevaluate.
#
# Evaluation results for complexity evaluator 2 already exist. Will not reevaluate.
#
# Finished ComplexityDifferenceEvaluator after 0:00:00.022523.
#
# Starting GeoflowOutputEvaluator ...
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.337555.
#
# Starting CityJSONBuildingsEvaluator ...
#
# Finished CityJSONBuildingsEvaluator after 0:00:01.416542.
#
# Starting WavefrontOBJBuildingsEvaluator ...
#
# Finished WavefrontOBJBuildingsEvaluator after 0:00:01.670361.
#
# Finished GeoflowOutputEvaluator after 0:00:03.427462.
#
# Running 'setup_evaluation' for optim_0000 ...
#
# Finished 'setup_evaluation' for optim_0000 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0001 ...
#
# Finished 'setup_evaluation' for optim_0001 after 0:00:00.017932.
#
# Running 'setup_evaluation' for optim_0002 ...
#
# Finished 'setup_evaluation' for optim_0002 after 0:00:00.018000.
#
# Running 'setup_evaluation' for optim_0003 ...
#
# Finished 'setup_evaluation' for optim_0003 after 0:00:00.017424.
#
# Running 'setup_evaluation' for optim_0004 ...
#
# Finished 'setup_evaluation' for optim_0004 after 0:00:00.017272.
#
# Running 'setup_evaluation' for optim_0005 ...
#
# Finished 'setup_evaluation' for optim_0005 after 0:00:00.016071.
#
# Running 'setup_evaluation' for optim_0006 ...
#
# Finished 'setup_evaluation' for optim_0006 after 0:00:00.016288.
#
# Running 'setup_evaluation' for optim_0007 ...
#
# Finished 'setup_evaluation' for optim_0007 after 0:00:00.016000.
#
# Running 'setup_evaluation' for optim_0008 ...
#
# Finished 'setup_evaluation' for optim_0008 after 0:00:00.015293.
#
# Running 'setup_evaluation' for optim_0009 ...
#
# Finished 'setup_evaluation' for optim_0009 after 0:00:00.015456.
#
# Running 'setup_evaluation' for optim_0010 ...
#
# Finished 'setup_evaluation' for optim_0010 after 0:00:00.014797.
#
# Running 'setup_evaluation' for optim_0011 ...
#
# Finished 'setup_evaluation' for optim_0011 after 0:00:00.016019.
#
# Running 'setup_evaluation' for optim_0012 ...
#
# Finished 'setup_evaluation' for optim_0012 after 0:00:00.017447.
#
# Running 'setup_evaluation' for optim_0013 ...
#
# Finished 'setup_evaluation' for optim_0013 after 0:00:00.015593.
#
# Running 'setup_evaluation' for optim_0014 ...
#
# Finished 'setup_evaluation' for optim_0014 after 0:00:00.015647.
#
# Running 'setup_evaluation' for optim_0015 ...
#
# Finished 'setup_evaluation' for optim_0015 after 0:00:00.016008.
#
# Running 'setup_evaluation' for optim_0016 ...
#
# Finished 'setup_evaluation' for optim_0016 after 0:00:00.014533.
#
# Running 'setup_evaluation' for optim_0017 ...
#
# Finished 'setup_evaluation' for optim_0017 after 0:00:00.015790.
#
# Running 'setup_evaluation' for optim_0018 ...
#
# Finished 'setup_evaluation' for optim_0018 after 0:00:00.014956.
#
# Running 'setup_evaluation' for optim_0019 ...
#
# Finished 'setup_evaluation' for optim_0019 after 0:00:00.016000.
#
# Running 'setup_evaluation' for optim_0020 ...
#
# Finished 'setup_evaluation' for optim_0020 after 0:00:00.016000.
#
# Running 'setup_evaluation' for optim_0021 ...
#
# Finished 'setup_evaluation' for optim_0021 after 0:00:00.016001.
#
# Running 'setup_evaluation' for optim_0022 ...
#
# Finished 'setup_evaluation' for optim_0022 after 0:00:00.016440.
#
# Running 'setup_evaluation' for optim_0023 ...
#
# Finished 'setup_evaluation' for optim_0023 after 0:00:00.015041.
#
# Running 'setup_evaluation' for optim_0024 ...
#
# Finished 'setup_evaluation' for optim_0024 after 0:00:00.015030.
#
# Running 'setup_evaluation' for optim_0025 ...
#
# Finished 'setup_evaluation' for optim_0025 after 0:00:00.016119.
#
# Running 'setup_evaluation' for optim_0026 ...
#
# Finished 'setup_evaluation' for optim_0026 after 0:00:00.015050.
#
# Running 'setup_evaluation' for optim_0027 ...
#
# Finished 'setup_evaluation' for optim_0027 after 0:00:00.015009.
#
# Running 'setup_evaluation' for optim_0028 ...
#
# Finished 'setup_evaluation' for optim_0028 after 0:00:00.015228.
#
# Running 'setup_evaluation' for optim_0029 ...
#
# Finished 'setup_evaluation' for optim_0029 after 0:00:00.015222.
#
# Running 'setup_evaluation' for optim_0030 ...
#
# Finished 'setup_evaluation' for optim_0030 after 0:00:00.015169.
#
# Running 'setup_evaluation' for optim_0031 ...
#
# Finished 'setup_evaluation' for optim_0031 after 0:00:00.015804.
#
# Running 'setup_evaluation' for optim_0032 ...
#
# Finished 'setup_evaluation' for optim_0032 after 0:00:00.014754.
#
# Running 'setup_evaluation' for optim_0033 ...
#
# Finished 'setup_evaluation' for optim_0033 after 0:00:00.017183.
#
# Running 'setup_evaluation' for optim_0034 ...
#
# Finished 'setup_evaluation' for optim_0034 after 0:00:00.014132.
#
# Running 'setup_evaluation' for optim_0035 ...
#
# Finished 'setup_evaluation' for optim_0035 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0036 ...
#
# Finished 'setup_evaluation' for optim_0036 after 0:00:00.015190.
#
# Running 'setup_evaluation' for optim_0037 ...
#
# Finished 'setup_evaluation' for optim_0037 after 0:00:00.015500.
#
# Running 'setup_evaluation' for optim_0038 ...
#
# Finished 'setup_evaluation' for optim_0038 after 0:00:00.014215.
#
# Running 'setup_evaluation' for optim_0039 ...
#
# Finished 'setup_evaluation' for optim_0039 after 0:00:00.015890.
#
# Running 'setup_evaluation' for optim_0040 ...
#
# Finished 'setup_evaluation' for optim_0040 after 0:00:00.014780.
#
# Running 'setup_evaluation' for optim_0041 ...
#
# Finished 'setup_evaluation' for optim_0041 after 0:00:00.013878.
#
# Running 'setup_evaluation' for optim_0042 ...
#
# Finished 'setup_evaluation' for optim_0042 after 0:00:00.015775.
#
# Running 'setup_evaluation' for optim_0043 ...
#
# Finished 'setup_evaluation' for optim_0043 after 0:00:00.014004.
#
# Running 'setup_evaluation' for optim_0044 ...
#
# Finished 'setup_evaluation' for optim_0044 after 0:00:00.014518.
#
# Running 'setup_evaluation' for optim_0045 ...
#
# Finished 'setup_evaluation' for optim_0045 after 0:00:00.014275.
#
# Running 'setup_evaluation' for optim_0046 ...
#
# Finished 'setup_evaluation' for optim_0046 after 0:00:00.014897.
#
# Running 'setup_evaluation' for optim_0047 ...
#
# Finished 'setup_evaluation' for optim_0047 after 0:00:00.015216.
#
# Running 'setup_evaluation' for optim_0048 ...
#
# Finished 'setup_evaluation' for optim_0048 after 0:00:00.014132.
#
# Running 'setup_evaluation' for optim_0049 ...
#
# Finished 'setup_evaluation' for optim_0049 after 0:00:00.018004.
#
# Running 'setup_evaluation' for optim_0050 ...
#
# Finished 'setup_evaluation' for optim_0050 after 0:00:00.016670.
#
# Finished running 1 step for 51 scenarios after 0:00:00.795653.
#
# Computing summary statistics of 51 scenarios in experiment scenario_118...
#
# WARNING: Reconstruction in optim_0001 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0002 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0009 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0010 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0011 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0012 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0014 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0016 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0018 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0024 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0025 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0029 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0036 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0038 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0039 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0041 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0044 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0050 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# Setting up reconstruction optimization ...
# - Setting up experiment ...
# - Setting up optimizer ...
#
# Loading experiment configuration ...
# File `scenario_settings.json` not found.
# Initializing experiment ...
# Loading scenarios ...
# - 51 scenarios
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_119/07_reconstruction/optim_0000/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_119/07_reconstruction/optim_0000/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_119\07_reconstruction\optim_0000\geoflow_log_241014-200620.txt
#
# Finished 3D building reconstruction after 0:17:58.904274.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.406125.
#
# Reconstruction in optim_0000 yielded 99 buildings.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_119\07_reconstruction\optim_0000\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:40.144543.
#
# Starting ComplexityEvaluator ...
#
# Counting faces for LOD 2.2 ...
#
# Finished ComplexityEvaluator after 0:00:02.031644.
#
# Starting ComplexityDifferenceEvaluator ...
#
# Evaluation results for complexity evaluator 1 already exist. Will not reevaluate.
#
# Evaluation results for complexity evaluator 2 already exist. Will not reevaluate.
#
# Finished ComplexityDifferenceEvaluator after 0:00:00.023000.
#
# Starting GeoflowOutputEvaluator ...
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.390602.
#
# Starting CityJSONBuildingsEvaluator ...
#
# Finished CityJSONBuildingsEvaluator after 0:00:01.557575.
#
# Starting WavefrontOBJBuildingsEvaluator ...
#
# Finished WavefrontOBJBuildingsEvaluator after 0:00:01.657918.
#
# Finished GeoflowOutputEvaluator after 0:00:03.610090.
#
# Running 'setup_evaluation' for optim_0000 ...
#
# Finished 'setup_evaluation' for optim_0000 after 0:00:00.015036.
#
# Running 'setup_evaluation' for optim_0001 ...
#
# Finished 'setup_evaluation' for optim_0001 after 0:00:00.016980.
#
# Running 'setup_evaluation' for optim_0002 ...
#
# Finished 'setup_evaluation' for optim_0002 after 0:00:00.016289.
#
# Running 'setup_evaluation' for optim_0003 ...
#
# Finished 'setup_evaluation' for optim_0003 after 0:00:00.015999.
#
# Running 'setup_evaluation' for optim_0004 ...
#
# Finished 'setup_evaluation' for optim_0004 after 0:00:00.016973.
#
# Running 'setup_evaluation' for optim_0005 ...
#
# Finished 'setup_evaluation' for optim_0005 after 0:00:00.015004.
#
# Running 'setup_evaluation' for optim_0006 ...
#
# Finished 'setup_evaluation' for optim_0006 after 0:00:00.015020.
#
# Running 'setup_evaluation' for optim_0007 ...
#
# Finished 'setup_evaluation' for optim_0007 after 0:00:00.014979.
#
# Running 'setup_evaluation' for optim_0008 ...
#
# Finished 'setup_evaluation' for optim_0008 after 0:00:00.016042.
#
# Running 'setup_evaluation' for optim_0009 ...
#
# Finished 'setup_evaluation' for optim_0009 after 0:00:00.015516.
#
# Running 'setup_evaluation' for optim_0010 ...
#
# Finished 'setup_evaluation' for optim_0010 after 0:00:00.016023.
#
# Running 'setup_evaluation' for optim_0011 ...
#
# Finished 'setup_evaluation' for optim_0011 after 0:00:00.015973.
#
# Running 'setup_evaluation' for optim_0012 ...
#
# Finished 'setup_evaluation' for optim_0012 after 0:00:00.017999.
#
# Running 'setup_evaluation' for optim_0013 ...
#
# Finished 'setup_evaluation' for optim_0013 after 0:00:00.017002.
#
# Running 'setup_evaluation' for optim_0014 ...
#
# Finished 'setup_evaluation' for optim_0014 after 0:00:00.020596.
#
# Running 'setup_evaluation' for optim_0015 ...
#
# Finished 'setup_evaluation' for optim_0015 after 0:00:00.016964.
#
# Running 'setup_evaluation' for optim_0016 ...
#
# Finished 'setup_evaluation' for optim_0016 after 0:00:00.014996.
#
# Running 'setup_evaluation' for optim_0017 ...
#
# Finished 'setup_evaluation' for optim_0017 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0018 ...
#
# Finished 'setup_evaluation' for optim_0018 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0019 ...
#
# Finished 'setup_evaluation' for optim_0019 after 0:00:00.016003.
#
# Running 'setup_evaluation' for optim_0020 ...
#
# Finished 'setup_evaluation' for optim_0020 after 0:00:00.016008.
#
# Running 'setup_evaluation' for optim_0021 ...
#
# Finished 'setup_evaluation' for optim_0021 after 0:00:00.014129.
#
# Running 'setup_evaluation' for optim_0022 ...
#
# Finished 'setup_evaluation' for optim_0022 after 0:00:00.015976.
#
# Running 'setup_evaluation' for optim_0023 ...
#
# Finished 'setup_evaluation' for optim_0023 after 0:00:00.014023.
#
# Running 'setup_evaluation' for optim_0024 ...
#
# Finished 'setup_evaluation' for optim_0024 after 0:00:00.015977.
#
# Running 'setup_evaluation' for optim_0025 ...
#
# Finished 'setup_evaluation' for optim_0025 after 0:00:00.020999.
#
# Running 'setup_evaluation' for optim_0026 ...
#
# Finished 'setup_evaluation' for optim_0026 after 0:00:00.018007.
#
# Running 'setup_evaluation' for optim_0027 ...
#
# Finished 'setup_evaluation' for optim_0027 after 0:00:00.020245.
#
# Running 'setup_evaluation' for optim_0028 ...
#
# Finished 'setup_evaluation' for optim_0028 after 0:00:00.018005.
#
# Running 'setup_evaluation' for optim_0029 ...
#
# Finished 'setup_evaluation' for optim_0029 after 0:00:00.017022.
#
# Running 'setup_evaluation' for optim_0030 ...
#
# Finished 'setup_evaluation' for optim_0030 after 0:00:00.013998.
#
# Running 'setup_evaluation' for optim_0031 ...
#
# Finished 'setup_evaluation' for optim_0031 after 0:00:00.014980.
#
# Running 'setup_evaluation' for optim_0032 ...
#
# Finished 'setup_evaluation' for optim_0032 after 0:00:00.016027.
#
# Running 'setup_evaluation' for optim_0033 ...
#
# Finished 'setup_evaluation' for optim_0033 after 0:00:00.015522.
#
# Running 'setup_evaluation' for optim_0034 ...
#
# Finished 'setup_evaluation' for optim_0034 after 0:00:00.014998.
#
# Running 'setup_evaluation' for optim_0035 ...
#
# Finished 'setup_evaluation' for optim_0035 after 0:00:00.013986.
#
# Running 'setup_evaluation' for optim_0036 ...
#
# Finished 'setup_evaluation' for optim_0036 after 0:00:00.015974.
#
# Running 'setup_evaluation' for optim_0037 ...
#
# Finished 'setup_evaluation' for optim_0037 after 0:00:00.015023.
#
# Running 'setup_evaluation' for optim_0038 ...
#
# Finished 'setup_evaluation' for optim_0038 after 0:00:00.017021.
#
# Running 'setup_evaluation' for optim_0039 ...
#
# Finished 'setup_evaluation' for optim_0039 after 0:00:00.016536.
#
# Running 'setup_evaluation' for optim_0040 ...
#
# Finished 'setup_evaluation' for optim_0040 after 0:00:00.014999.
#
# Running 'setup_evaluation' for optim_0041 ...
#
# Finished 'setup_evaluation' for optim_0041 after 0:00:00.015002.
#
# Running 'setup_evaluation' for optim_0042 ...
#
# Finished 'setup_evaluation' for optim_0042 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0043 ...
#
# Finished 'setup_evaluation' for optim_0043 after 0:00:00.015999.
#
# Running 'setup_evaluation' for optim_0044 ...
#
# Finished 'setup_evaluation' for optim_0044 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0045 ...
#
# Finished 'setup_evaluation' for optim_0045 after 0:00:00.014984.
#
# Running 'setup_evaluation' for optim_0046 ...
#
# Finished 'setup_evaluation' for optim_0046 after 0:00:00.014532.
#
# Running 'setup_evaluation' for optim_0047 ...
#
# Finished 'setup_evaluation' for optim_0047 after 0:00:00.015999.
#
# Running 'setup_evaluation' for optim_0048 ...
#
# Finished 'setup_evaluation' for optim_0048 after 0:00:00.014976.
#
# Running 'setup_evaluation' for optim_0049 ...
#
# Finished 'setup_evaluation' for optim_0049 after 0:00:00.016026.
#
# Running 'setup_evaluation' for optim_0050 ...
#
# Finished 'setup_evaluation' for optim_0050 after 0:00:00.016000.
#
# Finished running 1 step for 51 scenarios after 0:00:00.819368.
#
# Computing summary statistics of 51 scenarios in experiment scenario_119...
#
# WARNING: Reconstruction in optim_0001 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0003 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0010 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0013 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0020 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0024 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0026 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0027 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0028 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0029 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0039 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0044 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0047 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0049 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# Setting up reconstruction optimization ...
# - Setting up experiment ...
# - Setting up optimizer ...
#
# Loading experiment configuration ...
# File `scenario_settings.json` not found.
# Initializing experiment ...
# Loading scenarios ...
# - 51 scenarios
#
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_120/07_reconstruction/optim_0000/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_120/07_reconstruction/optim_0000/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_120\07_reconstruction\optim_0000\geoflow_log_241014-202509.txt
#
# Finished 3D building reconstruction after 0:18:23.089077.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.378433.
#
# Reconstruction in optim_0000 yielded 99 buildings.
#
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_120\07_reconstruction\optim_0000\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:41.313487.
#
# Starting ComplexityEvaluator ...
#
# Counting faces for LOD 2.2 ...
#
# Finished ComplexityEvaluator after 0:00:02.035709.
#
# Starting ComplexityDifferenceEvaluator ...
#
# Evaluation results for complexity evaluator 1 already exist. Will not reevaluate.
#
# Evaluation results for complexity evaluator 2 already exist. Will not reevaluate.
#
# Finished ComplexityDifferenceEvaluator after 0:00:00.023001.
#
# Starting GeoflowOutputEvaluator ...
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.380111.
#
# Starting CityJSONBuildingsEvaluator ...
#
# Finished CityJSONBuildingsEvaluator after 0:00:01.580787.
#
# Starting WavefrontOBJBuildingsEvaluator ...
#
# Finished WavefrontOBJBuildingsEvaluator after 0:00:01.755495.
#
# Finished GeoflowOutputEvaluator after 0:00:03.719391.
#
# Running 'setup_evaluation' for optim_0000 ...
#
# Finished 'setup_evaluation' for optim_0000 after 0:00:00.013991.
#
# Running 'setup_evaluation' for optim_0001 ...
#
# Finished 'setup_evaluation' for optim_0001 after 0:00:00.018998.
#
# Running 'setup_evaluation' for optim_0002 ...
#
# Finished 'setup_evaluation' for optim_0002 after 0:00:00.017001.
#
# Running 'setup_evaluation' for optim_0003 ...
#
# Finished 'setup_evaluation' for optim_0003 after 0:00:00.016006.
#
# Running 'setup_evaluation' for optim_0004 ...
#
# Finished 'setup_evaluation' for optim_0004 after 0:00:00.016509.
#
# Running 'setup_evaluation' for optim_0005 ...
#
# Finished 'setup_evaluation' for optim_0005 after 0:00:00.016999.
#
# Running 'setup_evaluation' for optim_0006 ...
#
# Finished 'setup_evaluation' for optim_0006 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0007 ...
#
# Finished 'setup_evaluation' for optim_0007 after 0:00:00.015036.
#
# Running 'setup_evaluation' for optim_0008 ...
#
# Finished 'setup_evaluation' for optim_0008 after 0:00:00.015964.
#
# Running 'setup_evaluation' for optim_0009 ...
#
# Finished 'setup_evaluation' for optim_0009 after 0:00:00.015005.
#
# Running 'setup_evaluation' for optim_0010 ...
#
# Finished 'setup_evaluation' for optim_0010 after 0:00:00.016511.
#
# Running 'setup_evaluation' for optim_0011 ...
#
# Finished 'setup_evaluation' for optim_0011 after 0:00:00.020000.
#
# Running 'setup_evaluation' for optim_0012 ...
#
# Finished 'setup_evaluation' for optim_0012 after 0:00:00.018000.
#
# Running 'setup_evaluation' for optim_0013 ...
#
# Finished 'setup_evaluation' for optim_0013 after 0:00:00.018004.
#
# Running 'setup_evaluation' for optim_0014 ...
#
# Finished 'setup_evaluation' for optim_0014 after 0:00:00.019995.
#
# Running 'setup_evaluation' for optim_0015 ...
#
# Finished 'setup_evaluation' for optim_0015 after 0:00:00.017004.
#
# Running 'setup_evaluation' for optim_0016 ...
#
# Finished 'setup_evaluation' for optim_0016 after 0:00:00.015265.
#
# Running 'setup_evaluation' for optim_0017 ...
#
# Finished 'setup_evaluation' for optim_0017 after 0:00:00.014000.
#
# Running 'setup_evaluation' for optim_0018 ...
#
# Finished 'setup_evaluation' for optim_0018 after 0:00:00.015001.
#
# Running 'setup_evaluation' for optim_0019 ...
#
# Finished 'setup_evaluation' for optim_0019 after 0:00:00.016035.
#
# Running 'setup_evaluation' for optim_0020 ...
#
# Finished 'setup_evaluation' for optim_0020 after 0:00:00.015002.
#
# Running 'setup_evaluation' for optim_0021 ...
#
# Finished 'setup_evaluation' for optim_0021 after 0:00:00.016042.
#
# Running 'setup_evaluation' for optim_0022 ...
#
# Finished 'setup_evaluation' for optim_0022 after 0:00:00.014572.
#
# Running 'setup_evaluation' for optim_0023 ...
#
# Finished 'setup_evaluation' for optim_0023 after 0:00:00.016002.
#
# Running 'setup_evaluation' for optim_0024 ...
#
# Finished 'setup_evaluation' for optim_0024 after 0:00:00.016985.
#
# Running 'setup_evaluation' for optim_0025 ...
#
# Finished 'setup_evaluation' for optim_0025 after 0:00:00.019978.
#
# Running 'setup_evaluation' for optim_0026 ...
#
# Finished 'setup_evaluation' for optim_0026 after 0:00:00.017025.
#
# Running 'setup_evaluation' for optim_0027 ...
#
# Finished 'setup_evaluation' for optim_0027 after 0:00:00.016990.
#
# Running 'setup_evaluation' for optim_0028 ...
#
# Finished 'setup_evaluation' for optim_0028 after 0:00:00.016552.
#
# Running 'setup_evaluation' for optim_0029 ...
#
# Finished 'setup_evaluation' for optim_0029 after 0:00:00.015992.
#
# Running 'setup_evaluation' for optim_0030 ...
#
# Finished 'setup_evaluation' for optim_0030 after 0:00:00.014965.
#
# Running 'setup_evaluation' for optim_0031 ...
#
# Finished 'setup_evaluation' for optim_0031 after 0:00:00.019037.
#
# Running 'setup_evaluation' for optim_0032 ...
#
# Finished 'setup_evaluation' for optim_0032 after 0:00:00.016999.
#
# Running 'setup_evaluation' for optim_0033 ...
#
# Finished 'setup_evaluation' for optim_0033 after 0:00:00.015042.
#
# Running 'setup_evaluation' for optim_0034 ...
#
# Finished 'setup_evaluation' for optim_0034 after 0:00:00.014515.
#
# Running 'setup_evaluation' for optim_0035 ...
#
# Finished 'setup_evaluation' for optim_0035 after 0:00:00.015996.
#
# Running 'setup_evaluation' for optim_0036 ...
#
# Finished 'setup_evaluation' for optim_0036 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0037 ...
#
# Finished 'setup_evaluation' for optim_0037 after 0:00:00.017000.
#
# Running 'setup_evaluation' for optim_0038 ...
#
# Finished 'setup_evaluation' for optim_0038 after 0:00:00.020000.
#
# Running 'setup_evaluation' for optim_0039 ...
#
# Finished 'setup_evaluation' for optim_0039 after 0:00:00.017004.
#
# Running 'setup_evaluation' for optim_0040 ...
#
# Finished 'setup_evaluation' for optim_0040 after 0:00:00.020516.
#
# Running 'setup_evaluation' for optim_0041 ...
#
# Finished 'setup_evaluation' for optim_0041 after 0:00:00.019005.
#
# Running 'setup_evaluation' for optim_0042 ...
#
# Finished 'setup_evaluation' for optim_0042 after 0:00:00.014995.
#
# Running 'setup_evaluation' for optim_0043 ...
#
# Finished 'setup_evaluation' for optim_0043 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0044 ...
#
# Finished 'setup_evaluation' for optim_0044 after 0:00:00.016000.
#
# Running 'setup_evaluation' for optim_0045 ...
#
# Finished 'setup_evaluation' for optim_0045 after 0:00:00.015005.
#
# Running 'setup_evaluation' for optim_0046 ...
#
# Finished 'setup_evaluation' for optim_0046 after 0:00:00.015509.
#
# Running 'setup_evaluation' for optim_0047 ...
#
# Finished 'setup_evaluation' for optim_0047 after 0:00:00.014999.
#
# Running 'setup_evaluation' for optim_0048 ...
#
# Finished 'setup_evaluation' for optim_0048 after 0:00:00.015001.
#
# Running 'setup_evaluation' for optim_0049 ...
#
# Finished 'setup_evaluation' for optim_0049 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0050 ...
#
# Finished 'setup_evaluation' for optim_0050 after 0:00:00.020000.
#
# Finished running 1 step for 51 scenarios after 0:00:00.846044.
#
# Computing summary statistics of 51 scenarios in experiment scenario_120...
#
# WARNING: Reconstruction in optim_0001 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0008 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0049 yielded zero buildings. Skipping all evaluators that require reconstructed building models.
#
# WARNING: Reconstruction in optim_0050 yielded zero buildings. Skipping all evaluators that require reconstructed building models.

# %% [markdown]
# # Rerun optim_0000 for scenario_048 and 037

# %%
scenario_id = 37

# %%
e[scenario_id].setup_reconstruction_optimization()
e[scenario_id].recon_optim.load_optim_experiment()
# Out:
# Setting up reconstruction optimization ...
# - Setting up experiment ...
# - Setting up optimizer ...
#
# Loading experiment configuration ...
# File `scenario_settings.json` not found.
# Initializing experiment ...
# Loading scenarios ...
# - 51 scenarios

# %%
add_geoflow_params = {"skip_lod12": True, "skip_lod13": True}
e[scenario_id].recon_optim.optim_experiment[0].setup_reconstruction(add_geoflow_params=add_geoflow_params, geoflow_timeout=None)
e[scenario_id].recon_optim.optim_experiment[0].prepare_reconstruction()

# %%
e[scenario_id].recon_optim.optim_experiment[0].run_reconstruction()
# Out:
# Starting 3D building reconstruction ...
# - Command: geof C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_037/07_reconstruction/optim_0000/reconstruct.json --verbose --workdir --config C:/Users/Florian/Data/city-to-scan-to-city/utrecht_10-492-594_v2/06_reconstruction_optimization/scenario_037/07_reconstruction/optim_0000/config.toml
# - Output log file: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_037\07_reconstruction\optim_0000\geoflow_log_241014-184401.txt
#
# Finished 3D building reconstruction after 0:00:08.692701.
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.044554.
#
# Reconstruction in optim_0000 yielded 99 buildings.

# %%
e[scenario_id].recon_optim.optim_experiment[0].setup_evaluation(lods="2.2")

# %%
e[scenario_id].recon_optim.optim_experiment[0].run_evaluation(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"])
# Out:
# Starting HausdorffLODSEvaluator ...
#
# This HausdorffLODSEvaluator is bidirectional.
#
# Setting up a HausdorffEvaluator (bidirectional) for each LOD ...
#
# Running HausdorffEvaluator for LOD '22' ...
#
# Splitting OBJ files into one file per individual object ...
#
# Identifying individual OBJ files present in both input datasets ...
# - Directories:
#   Input 1: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\01_input\OBJ\10-492-594_LOD22_mat_python
#   Input 2: C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_037\07_reconstruction\optim_0000\output\model_lod22
# - File comparison: Found 1084 unique OBJ file names in total, of which
#   99 file names present both directories
#   985 file names present only in directory 1
#   0 file names present only in directory 2
# Computing bidirectional Hausdorff distances between split OBJ files ...
#
# - All done.
#
# Joining results ...
#
# Finished HausdorffLODSEvaluator after 0:00:05.538866.
#
# Starting ComplexityEvaluator ...
#
# Counting faces for LOD 2.2 ...
#
# Finished ComplexityEvaluator after 0:00:00.079515.
#
# Starting ComplexityDifferenceEvaluator ...
#
# Evaluation results for complexity evaluator 1 already exist. Will not reevaluate.
#
# Evaluation results for complexity evaluator 2 already exist. Will not reevaluate.
#
# Finished ComplexityDifferenceEvaluator after 0:00:00.022036.
#
# Starting GeoflowOutputEvaluator ...
#
# Starting GeopackageBuildingsEvaluator ...
#
# Finished GeopackageBuildingsEvaluator after 0:00:00.042989.
#
# Starting CityJSONBuildingsEvaluator ...
#
# Finished CityJSONBuildingsEvaluator after 0:00:00.188124.
#
# Starting WavefrontOBJBuildingsEvaluator ...
#
# Finished WavefrontOBJBuildingsEvaluator after 0:00:00.095562.
#
# Finished GeoflowOutputEvaluator after 0:00:00.328642.

# %% [markdown]
# Summary stats from first attempt (after original):

# %%
e[48].recon_optim.optim_experiment[0].get_summary_statistics(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"])
# Out:
# {'hausdorff_22_rms': 18.431368109749204,
#  'hausdorff_22_mean': 4.641284798394249,
#  'hausdorff_22_median': 2.4238131046295166,
#  'hausdorff_22_min': 0.05699934437870979,
#  'hausdorff_22_max': 179.67298889160156,
#  'rms_min_dist_22_rms': 4.342110122659195,
#  'rms_min_dist_22_mean': 0.9740868862145297,
#  'rms_min_dist_22_median': 0.3189330809084752,
#  'rms_min_dist_22_min': 0.01856285590827789,
#  'rms_min_dist_22_max': 42.43379572464923,
#  'n_faces_22_count': 99.0,
#  'n_faces_22_mean': 179.66666666666666,
#  'n_faces_22_std': 204.37490560442183,
#  'n_faces_22_min': 12.0,
#  'n_faces_22_median': 104.0,
#  'n_faces_22_max': 966.0,
#  'n_faces_22_diff_mean': 66.37373737373737,
#  'n_faces_22_diff_std': 93.45899306577779,
#  'n_faces_22_diff_min': -98.0,
#  'n_faces_22_diff_median': 34.0,
#  'n_faces_22_diff_max': 460.0,
#  'n_faces_22_abs_diff_mean': 73.70707070707071,
#  'n_faces_22_abs_diff_std': 87.7316470167434,
#  'n_faces_22_abs_diff_min': 0.0,
#  'n_faces_22_abs_diff_median': 36.0,
#  'n_faces_22_abs_diff_max': 460.0,
#  'n_faces_22_ratio_mean': 1.9589760923502169,
#  'n_faces_22_ratio_std': 0.9818333059159194,
#  'n_faces_22_ratio_min': 0.5853658536585366,
#  'n_faces_22_ratio_median': 1.8125,
#  'n_faces_22_ratio_max': 5.666666666666667,
#  'n_faces_22_norm_diff_mean': 0.958976092350217,
#  'n_faces_22_norm_diff_std': 0.9818333059159196,
#  'n_faces_22_norm_diff_min': -0.4146341463414634,
#  'n_faces_22_norm_diff_median': 0.8125,
#  'n_faces_22_norm_diff_max': 4.666666666666667,
#  'n_faces_22_norm_abs_diff_mean': 1.0097795710533117,
#  'n_faces_22_norm_abs_diff_std': 0.928954463713693,
#  'n_faces_22_norm_abs_diff_min': 0.0,
#  'n_faces_22_norm_abs_diff_median': 0.8125,
#  'n_faces_22_norm_abs_diff_max': 4.666666666666667,
#  'gpkg_total_22': 108,
#  'gpkg_unique_22': 99,
#  'gpkg_multiple_22': 4,
#  'cj_buildings': 100,
#  'cj_building_parts': 108,
#  'cj_buildings_with_bp': 99,
#  'cj_buildings_zero_bp': 1,
#  'cj_buildings_one_bp': 95,
#  'cj_buildings_multiple_bp': 4}

# %% [markdown]
# Summary stats from second attempt (after original):

# %%
e[48].recon_optim.optim_experiment[0].get_summary_statistics(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"])
# Out:
# {'hausdorff_22_rms': 3.784218639987789,
#  'hausdorff_22_mean': 2.9096434658600225,
#  'hausdorff_22_median': 2.4238131046295166,
#  'hausdorff_22_min': 0.05699934437870979,
#  'hausdorff_22_max': 8.714778900146484,
#  'rms_min_dist_22_rms': 0.8293215807428279,
#  'rms_min_dist_22_mean': 0.5598914675462001,
#  'rms_min_dist_22_median': 0.31443842619118695,
#  'rms_min_dist_22_min': 0.018620240628682554,
#  'rms_min_dist_22_max': 3.4563919608279825,
#  'n_faces_22_count': 99.0,
#  'n_faces_22_mean': 179.7171717171717,
#  'n_faces_22_std': 204.65456413305475,
#  'n_faces_22_min': 12.0,
#  'n_faces_22_median': 104.0,
#  'n_faces_22_max': 970.0,
#  'n_faces_22_diff_mean': 66.42424242424242,
#  'n_faces_22_diff_std': 93.57961697095381,
#  'n_faces_22_diff_min': -98.0,
#  'n_faces_22_diff_median': 34.0,
#  'n_faces_22_diff_max': 460.0,
#  'n_faces_22_abs_diff_mean': 73.6969696969697,
#  'n_faces_22_abs_diff_std': 87.9072394392271,
#  'n_faces_22_abs_diff_min': 0.0,
#  'n_faces_22_abs_diff_median': 36.0,
#  'n_faces_22_abs_diff_max': 460.0,
#  'n_faces_22_ratio_mean': 1.9586959336302208,
#  'n_faces_22_ratio_std': 0.9818715149027146,
#  'n_faces_22_ratio_min': 0.5853658536585366,
#  'n_faces_22_ratio_median': 1.8125,
#  'n_faces_22_ratio_max': 5.666666666666667,
#  'n_faces_22_norm_diff_mean': 0.9586959336302205,
#  'n_faces_22_norm_diff_std': 0.9818715149027146,
#  'n_faces_22_norm_diff_min': -0.4146341463414634,
#  'n_faces_22_norm_diff_median': 0.8125,
#  'n_faces_22_norm_diff_max': 4.666666666666667,
#  'n_faces_22_norm_abs_diff_mean': 1.0091804330669678,
#  'n_faces_22_norm_abs_diff_std': 0.9293603558191625,
#  'n_faces_22_norm_abs_diff_min': 0.0,
#  'n_faces_22_norm_abs_diff_median': 0.8125,
#  'n_faces_22_norm_abs_diff_max': 4.666666666666667,
#  'gpkg_total_22': 108,
#  'gpkg_unique_22': 99,
#  'gpkg_multiple_22': 4,
#  'cj_buildings': 100,
#  'cj_building_parts': 108,
#  'cj_buildings_with_bp': 99,
#  'cj_buildings_zero_bp': 1,
#  'cj_buildings_one_bp': 95,
#  'cj_buildings_multiple_bp': 4}

# %% [markdown]
# Summary stats from third attempt (after original):

# %%
e[48].recon_optim.optim_experiment[0].get_summary_statistics(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"])
# Out:
# {'hausdorff_22_rms': 3.7839560054219636,
#  'hausdorff_22_mean': 2.909453480194012,
#  'hausdorff_22_median': 2.4238131046295166,
#  'hausdorff_22_min': 0.05699934437870979,
#  'hausdorff_22_max': 8.714778900146484,
#  'rms_min_dist_22_rms': 0.8287265633495821,
#  'rms_min_dist_22_mean': 0.5598618080936618,
#  'rms_min_dist_22_median': 0.31675773896925224,
#  'rms_min_dist_22_min': 0.018545360709879277,
#  'rms_min_dist_22_max': 3.4506744003483942,
#  'n_faces_22_count': 99.0,
#  'n_faces_22_mean': 179.8989898989899,
#  'n_faces_22_std': 205.41796589698527,
#  'n_faces_22_min': 12.0,
#  'n_faces_22_median': 104.0,
#  'n_faces_22_max': 994.0,
#  'n_faces_22_diff_mean': 66.60606060606061,
#  'n_faces_22_diff_std': 94.07149020301898,
#  'n_faces_22_diff_min': -98.0,
#  'n_faces_22_diff_median': 34.0,
#  'n_faces_22_diff_max': 460.0,
#  'n_faces_22_abs_diff_mean': 73.91919191919192,
#  'n_faces_22_abs_diff_std': 88.38144102529496,
#  'n_faces_22_abs_diff_min': 0.0,
#  'n_faces_22_abs_diff_median': 36.0,
#  'n_faces_22_abs_diff_max': 460.0,
#  'n_faces_22_ratio_mean': 1.959482313591267,
#  'n_faces_22_ratio_std': 0.9805166661133295,
#  'n_faces_22_ratio_min': 0.5853658536585366,
#  'n_faces_22_ratio_median': 1.8125,
#  'n_faces_22_ratio_max': 5.666666666666667,
#  'n_faces_22_norm_diff_mean': 0.9594823135912669,
#  'n_faces_22_norm_diff_std': 0.9805166661133295,
#  'n_faces_22_norm_diff_min': -0.4146341463414634,
#  'n_faces_22_norm_diff_median': 0.8125,
#  'n_faces_22_norm_diff_max': 4.666666666666667,
#  'n_faces_22_norm_abs_diff_mean': 1.0101794658722458,
#  'n_faces_22_norm_abs_diff_std': 0.9276517385816837,
#  'n_faces_22_norm_abs_diff_min': 0.0,
#  'n_faces_22_norm_abs_diff_median': 0.8125,
#  'n_faces_22_norm_abs_diff_max': 4.666666666666667,
#  'gpkg_total_22': 108,
#  'gpkg_unique_22': 99,
#  'gpkg_multiple_22': 4,
#  'cj_buildings': 100,
#  'cj_building_parts': 108,
#  'cj_buildings_with_bp': 99,
#  'cj_buildings_zero_bp': 1,
#  'cj_buildings_one_bp': 95,
#  'cj_buildings_multiple_bp': 4}

# %% [markdown]
# Summary stats for first attempt (after original) of scenario 37's optim_0000:

# %%
e[scenario_id].recon_optim.optim_experiment[0].get_summary_statistics(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"])
# Out:
# {'hausdorff_22_rms': 4.49230886188208,
#  'hausdorff_22_mean': 3.3805000903178946,
#  'hausdorff_22_median': 2.4176244735717773,
#  'hausdorff_22_min': 0.06685002148151398,
#  'hausdorff_22_max': 10.628173828125,
#  'rms_min_dist_22_rms': 0.9740300705975379,
#  'rms_min_dist_22_mean': 0.6690254074447283,
#  'rms_min_dist_22_median': 0.36063238556164406,
#  'rms_min_dist_22_min': 0.019713106064374788,
#  'rms_min_dist_22_max': 2.830117127429148,
#  'n_faces_22_count': 99.0,
#  'n_faces_22_mean': 140.66666666666666,
#  'n_faces_22_std': 145.04770503077214,
#  'n_faces_22_min': 12.0,
#  'n_faces_22_median': 82.0,
#  'n_faces_22_max': 874.0,
#  'n_faces_22_diff_mean': 27.373737373737374,
#  'n_faces_22_diff_std': 61.319435587646,
#  'n_faces_22_diff_min': -250.0,
#  'n_faces_22_diff_median': 28.0,
#  'n_faces_22_diff_max': 166.0,
#  'n_faces_22_abs_diff_mean': 49.41414141414141,
#  'n_faces_22_abs_diff_std': 45.280984453541194,
#  'n_faces_22_abs_diff_min': 0.0,
#  'n_faces_22_abs_diff_median': 36.0,
#  'n_faces_22_abs_diff_max': 250.0,
#  'n_faces_22_ratio_mean': 1.7299936873565556,
#  'n_faces_22_ratio_std': 1.0603259852629376,
#  'n_faces_22_ratio_min': 0.1951219512195122,
#  'n_faces_22_ratio_median': 1.4545454545454546,
#  'n_faces_22_ratio_max': 4.75,
#  'n_faces_22_norm_diff_mean': 0.7299936873565558,
#  'n_faces_22_norm_diff_std': 1.0603259852629376,
#  'n_faces_22_norm_diff_min': -0.8048780487804879,
#  'n_faces_22_norm_diff_median': 0.45454545454545453,
#  'n_faces_22_norm_diff_max': 3.75,
#  'n_faces_22_norm_abs_diff_mean': 0.9000584532386364,
#  'n_faces_22_norm_abs_diff_std': 0.9188297125292741,
#  'n_faces_22_norm_abs_diff_min': 0.0,
#  'n_faces_22_norm_abs_diff_median': 0.5714285714285714,
#  'n_faces_22_norm_abs_diff_max': 3.75,
#  'gpkg_total_22': 105,
#  'gpkg_unique_22': 99,
#  'gpkg_multiple_22': 4,
#  'cj_buildings': 100,
#  'cj_building_parts': 105,
#  'cj_buildings_with_bp': 99,
#  'cj_buildings_zero_bp': 1,
#  'cj_buildings_one_bp': 95,
#  'cj_buildings_multiple_bp': 4}

# %%
e[scenario_id].recon_optim.optim_experiment[0].concat_evaluation_results(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"])

# %%
e[scenario_id].recon_optim.optim_experiment.run_steps(Scenario.setup_evaluation, lods=["2.2"])
e[scenario_id].recon_optim.optim_experiment.compute_summary_statistics(evaluator_selection=["hausdorff", "complexity", "complexity_diff", "geoflow_output"], ignore_missing=True)
# Out:
# Running 'setup_evaluation' for optim_0000 ...
#
# Finished 'setup_evaluation' for optim_0000 after 0:00:00.018004.
#
# Running 'setup_evaluation' for optim_0001 ...
#
# Finished 'setup_evaluation' for optim_0001 after 0:00:00.018995.
#
# Running 'setup_evaluation' for optim_0002 ...
#
# Finished 'setup_evaluation' for optim_0002 after 0:00:00.015002.
#
# Running 'setup_evaluation' for optim_0003 ...
#
# Finished 'setup_evaluation' for optim_0003 after 0:00:00.016003.
#
# Running 'setup_evaluation' for optim_0004 ...
#
# Finished 'setup_evaluation' for optim_0004 after 0:00:00.015249.
#
# Running 'setup_evaluation' for optim_0005 ...
#
# Finished 'setup_evaluation' for optim_0005 after 0:00:00.016001.
#
# Running 'setup_evaluation' for optim_0006 ...
#
# Finished 'setup_evaluation' for optim_0006 after 0:00:00.017971.
#
# Running 'setup_evaluation' for optim_0007 ...
#
# Finished 'setup_evaluation' for optim_0007 after 0:00:00.016993.
#
# Running 'setup_evaluation' for optim_0008 ...
#
# Finished 'setup_evaluation' for optim_0008 after 0:00:00.015999.
#
# Running 'setup_evaluation' for optim_0009 ...
#
# Finished 'setup_evaluation' for optim_0009 after 0:00:00.015007.
#
# Running 'setup_evaluation' for optim_0010 ...
#
# Finished 'setup_evaluation' for optim_0010 after 0:00:00.015589.
#
# Running 'setup_evaluation' for optim_0011 ...
#
# Finished 'setup_evaluation' for optim_0011 after 0:00:00.014358.
#
# Running 'setup_evaluation' for optim_0012 ...
#
# Finished 'setup_evaluation' for optim_0012 after 0:00:00.016000.
#
# Running 'setup_evaluation' for optim_0013 ...
#
# Finished 'setup_evaluation' for optim_0013 after 0:00:00.015967.
#
# Running 'setup_evaluation' for optim_0014 ...
#
# Finished 'setup_evaluation' for optim_0014 after 0:00:00.015519.
#
# Running 'setup_evaluation' for optim_0015 ...
#
# Finished 'setup_evaluation' for optim_0015 after 0:00:00.016006.
#
# Running 'setup_evaluation' for optim_0016 ...
#
# Finished 'setup_evaluation' for optim_0016 after 0:00:00.016517.
#
# Running 'setup_evaluation' for optim_0017 ...
#
# Finished 'setup_evaluation' for optim_0017 after 0:00:00.016516.
#
# Running 'setup_evaluation' for optim_0018 ...
#
# Finished 'setup_evaluation' for optim_0018 after 0:00:00.017384.
#
# Running 'setup_evaluation' for optim_0019 ...
#
# Finished 'setup_evaluation' for optim_0019 after 0:00:00.017471.
#
# Running 'setup_evaluation' for optim_0020 ...
#
# Finished 'setup_evaluation' for optim_0020 after 0:00:00.134543.
#
# Running 'setup_evaluation' for optim_0021 ...
#
# Finished 'setup_evaluation' for optim_0021 after 0:00:00.018408.
#
# Running 'setup_evaluation' for optim_0022 ...
#
# Finished 'setup_evaluation' for optim_0022 after 0:00:00.017181.
#
# Running 'setup_evaluation' for optim_0023 ...
#
# Finished 'setup_evaluation' for optim_0023 after 0:00:00.015999.
#
# Running 'setup_evaluation' for optim_0024 ...
#
# Finished 'setup_evaluation' for optim_0024 after 0:00:00.016437.
#
# Running 'setup_evaluation' for optim_0025 ...
#
# Finished 'setup_evaluation' for optim_0025 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0026 ...
#
# Finished 'setup_evaluation' for optim_0026 after 0:00:00.016007.
#
# Running 'setup_evaluation' for optim_0027 ...
#
# Finished 'setup_evaluation' for optim_0027 after 0:00:00.019129.
#
# Running 'setup_evaluation' for optim_0028 ...
#
# Finished 'setup_evaluation' for optim_0028 after 0:00:00.015744.
#
# Running 'setup_evaluation' for optim_0029 ...
#
# Finished 'setup_evaluation' for optim_0029 after 0:00:00.016998.
#
# Running 'setup_evaluation' for optim_0030 ...
#
# Finished 'setup_evaluation' for optim_0030 after 0:00:00.015000.
#
# Running 'setup_evaluation' for optim_0031 ...
#
# Finished 'setup_evaluation' for optim_0031 after 0:00:00.014999.
#
# Running 'setup_evaluation' for optim_0032 ...
#
# Finished 'setup_evaluation' for optim_0032 after 0:00:00.015004.
#
# Running 'setup_evaluation' for optim_0033 ...
#
# Finished 'setup_evaluation' for optim_0033 after 0:00:00.014506.
#
# Running 'setup_evaluation' for optim_0034 ...
#
# Finished 'setup_evaluation' for optim_0034 after 0:00:00.019015.
#
# Running 'setup_evaluation' for optim_0035 ...
#
# Finished 'setup_evaluation' for optim_0035 after 0:00:00.016992.
#
# Running 'setup_evaluation' for optim_0036 ...
#
# Finished 'setup_evaluation' for optim_0036 after 0:00:00.018000.
#
# Running 'setup_evaluation' for optim_0037 ...
#
# Finished 'setup_evaluation' for optim_0037 after 0:00:00.016999.
#
# Running 'setup_evaluation' for optim_0038 ...
#
# Finished 'setup_evaluation' for optim_0038 after 0:00:00.016005.
#
# Running 'setup_evaluation' for optim_0039 ...
#
# Finished 'setup_evaluation' for optim_0039 after 0:00:00.017514.
#
# Running 'setup_evaluation' for optim_0040 ...
#
# Finished 'setup_evaluation' for optim_0040 after 0:00:00.016004.
#
# Running 'setup_evaluation' for optim_0041 ...
#
# Finished 'setup_evaluation' for optim_0041 after 0:00:00.014997.
#
# Running 'setup_evaluation' for optim_0042 ...
#
# Finished 'setup_evaluation' for optim_0042 after 0:00:00.014999.
#
# Running 'setup_evaluation' for optim_0043 ...
#
# Finished 'setup_evaluation' for optim_0043 after 0:00:00.015001.
#
# Running 'setup_evaluation' for optim_0044 ...
#
# Finished 'setup_evaluation' for optim_0044 after 0:00:00.014000.
#
# Running 'setup_evaluation' for optim_0045 ...
#
# Finished 'setup_evaluation' for optim_0045 after 0:00:00.014005.
#
# Running 'setup_evaluation' for optim_0046 ...
#
# Finished 'setup_evaluation' for optim_0046 after 0:00:00.015516.
#
# Running 'setup_evaluation' for optim_0047 ...
#
# Finished 'setup_evaluation' for optim_0047 after 0:00:00.014997.
#
# Running 'setup_evaluation' for optim_0048 ...
#
# Finished 'setup_evaluation' for optim_0048 after 0:00:00.019999.
#
# Running 'setup_evaluation' for optim_0049 ...
#
# Finished 'setup_evaluation' for optim_0049 after 0:00:00.018000.
#
# Running 'setup_evaluation' for optim_0050 ...
#
# Finished 'setup_evaluation' for optim_0050 after 0:00:00.017000.
#
# Finished running 1 step for 51 scenarios after 0:00:00.954586.
#
# Computing summary statistics of 51 scenarios in experiment scenario_037...

# %% [markdown]
# Dataset-level check for outliers in the OBJ files does not detect these faulty vertices in individual buildings. Should have done a building-level check!

# %%
from experiment.obj_file import OBJFile

# %%
o = OBJFile(r"C:\Users\Florian\Data\city-to-scan-to-city\utrecht_10-492-594_v2\06_reconstruction_optimization\scenario_048\07_reconstruction\optim_0000_backup\output\model_lod22.obj")

# %%
o.has_outlier_vertices(threshold=1e3)
# Out:
# False
